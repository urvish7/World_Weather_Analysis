# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

#additional dependencies
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import API key
#from config import g_key
# %store -r g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
## ADDITIONAL CODE TO MAKE THINGS WORK 

#Running a code as the system facing issues on fetching the data
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
 #Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1  
import requests
#from config import weather_api_key
# %store -r weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key
url
print(cities)
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ojinaga mx
# punta arenas cl
# cidreira br
# rikitea pf
# khatanga ru
# ilulissat gl
# busselton au
# punta arenas cl
# yellowknife ca
# rikitea pf
# hay river ca
# monte alegre de sergipe br
# bluff nz
# odweyne so
# naryan-mar ru
# sao filipe cv
# san ignacio pe
# vysokogornyy ru
# atuona pf
# punta arenas cl
# vao nc
# olafsvik is
# illoqqortoormiut gl
# gweta bw
# namibe ao
# bengkulu id
# banda aceh id
# klaksvik fo
# rikitea pf
# fort morgan us
# east london za
# barentsburg sj
# bequimao br
# roebourne au
# mount gambier au
# busselton au
# ushuaia ar
# san cristobal ec
# sawtell au
# fortuna us
# yellowknife ca
# cape town za
# bluff nz
# caravelas br
# new norfolk au
# ribeira grande pt
# esperance au
# maldonado uy
# ilulissat gl
# faanui pf
# sola vu
# hermanus za
# matara lk
# tiksi ru
# ushuaia ar
# ochakiv ua
# vila velha br
# chuy uy
# umzimvubu za
# hobyo so
# axim gh
# qaanaaq gl
# belushya guba ru
# tubruq ly
# cascais pt
# airai pw
# punta arenas cl
# faya td
# new norfolk au
# sudak ua
# praia da vitoria pt
# mutsamudu km
# busselton au
# sault sainte marie ca
# port alfred za
# rio grande br
# belushya guba ru
# ponta do sol cv
# taolanaro mg
# coquimbo cl
# ixtapa mx
# aksarka ru
# hermanus za
# portland au
# rikitea pf
# hilo us
# mataura pf
# touho nc
# airai pw
# ushuaia ar
# kruisfontein za
# mumford gh
# albany au
# ushuaia ar
# nizhneyansk ru
# kapaa us
# beringovskiy ru
# new norfolk au
# kangaatsiaq gl
# avarua ck
# monticello us
# vestmannaeyjar is
# wanning cn
# saint anthony ca
# kapaa us
# port hedland au
# asau tv
# sturgeon bay us
# bambous virieux mu
# hobart au
# mataura pf
# tiksi ru
# arraial do cabo br
# east london za
# kenora ca
# hermanus za
# kruisfontein za
# toungoo mm
# tasiilaq gl
# saint-philippe re
# nhulunbuy au
# ushuaia ar
# inhambane mz
# punta arenas cl
# cape town za
# lasa cn
# rikitea pf
# upernavik gl
# codrington ag
# ancud cl
# vrangel ru
# cape town za
# saint-philippe re
# ushuaia ar
# chuy uy
# samarai pg
# upernavik gl
# jamestown sh
# esmeraldas ec
on', 'qui nhon', 'henties bay', 'avera', 'araouane', 'kumluca', 'flin flon', 'bulawayo', 'guanica', 'develi', 'vanavara', 'hasaki', 'saint-pierre', 'pangnirtung', 'sao joao da barra', 'ratodero', 'tsihombe', 'comodoro rivadavia', 'nuuk', 'oussouye', 'port macquarie', 'lake wales', 'yerbogachen', 'amursk', 'palmer', 'roros', 'saint marys', 'la victoria', 'swan hill', 'takaka', 'bam', 'nome', 'campo maior', 'sinnamary', 'selenduma', 'qaqortoq', 'montepuez', 'arkhangelos', 'aleksandrovka', 'road town', 'alice springs', 'luis correia', 'provideniya', 'qinhuangdao', 'santiago', 'mouila', 'lebu', 'mys shmidta', 'dunedin', 'adra', 'cabo san lucas', 'turayf', 'sept-iles', 'pengcheng', 'shambu', 'bestobe', 'cardston', 'lavrentiya', 'bella vista', 'along', 'padang', 'quatre cocos', 'celestun', 'nakamura', 'clyde river', 'vostok', 'lolua', 'bambanglipuro', 'shache', 'wagar', 'guerrero negro', 'buraydah', 'port moresby', 'forbes', 'bilibino', 'dolbeau', 'marigot', 'luwuk', 'chicama', 'pueblo nuevo', 'daru', 'makueni', 'villefranche-sur-saone', 'lompoc', 'souillac', 'krasnoselkup', 'cap malheureux', 'vreed en hoop', 'mandera', 'varhaug', 'port lincoln', 'chiang khong', 'mecca', 'akdepe', 'thompson', 'vila franca do campo', 'novikovo', 'najran', 'alexandria', 'severo-kurilsk', 'gushikawa', 'cherskiy', 'brae', 'angol', 'maceio', 'kutum', 'presidencia roque saenz pena', 'margate', 'aklavik', 'marzuq', 'ponta pora', 'longyearbye ...
# Processing Record 1 of Set 1 | ojinaga
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | hay river
# Processing Record 10 of Set 1 | monte alegre de sergipe
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | odweyne
# Processing Record 13 of Set 1 | naryan-mar
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | san ignacio
# Processing Record 16 of Set 1 | vysokogornyy
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | vao
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | gweta
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | banda aceh
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | fort morgan
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record
# Processing Record 27 of Set 4 | goderich
# Processing Record 28 of Set 4 | waddan
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | riyadh
# Processing Record 31 of Set 4 | yar-sale
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | quelimane
# Processing Record 34 of Set 4 | sao miguel do araguaia
# Processing Record 35 of Set 4 | adre
# Processing Record 36 of Set 4 | moussoro
# Processing Record 37 of Set 4 | pevek
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | hibbing
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | george town
# Processing Record 43 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 44 of Set 4 | santa cruz do sul
# Processing Record 45 of Set 4 | tha chang
# Processing Record 46 of Set 4 | hailin
# Processing Record 47 of Set 4 | arlit
# Processing Record 48 of Set 4 | bealanana
# Processing Record 49 of Set 4 | guiratinga
# Processing Record 50 of Set 4 | santa maria
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 5 | bara
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | qui nhon
# Processing Record 6 of Set 5 | henties bay
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | araouane
# Processing Record 9 of Set 5 | kumluca
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | bulawayo
# Processing Record 12 of Set 5 | guanica
# Processing Record 13 of Set 5 | develi
# Processing Record 14 of Set 5 | vanavara
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | sao joao da barra
# Processing Record 19 of Set 5 | ratodero
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | comodoro rivadavia
# Processing Record 22 of Set 5 | nuuk
# Processing Record 23 of Set 5 | oussouye
# Processing Record 24 of Set 5 | port macquarie
# Processing Record 25 of Set 5 | lake wales
# Processing Record 26 of Set 5 | yerbogachen
# Processing Record 27 of Set 5 | amursk
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | roros
# Processing Record 30 of Set 5 | saint marys
# Processing Record 31 of Set 5 | la victoria
# Processing Record 32 of Set 5 | swan hill
# Processing Record 33 of Set 5 | takaka
# Processing Record 34 of Set 5 | bam
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | campo maior
# Processing Record 37 of Set 5 | sinnamary
# Processing Record 38 of Set 5 | selenduma
# Processing Record 39 of Set 5 | qaqortoq
# Processing Record 40 of Set 5 | montepuez
# Processing Record 41 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 42 of Set 5 | aleksandrovka
# Processing Record 43 of Set 5 | road town
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | luis correia
# Processing Record 46 of Set 5 | provideniya
# Processing Record 47 of Set 5 | qinhuangdao
# Processing Record 48 of Set 5 | santiago
# Processing Record 49 of Set 5 | mouila
# Processing Record 50 of Set 5 | lebu
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | dunedin
# Processing Record 3 of Set 6 | adra
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | turayf
# Processing Record 6 of Set 6 | sept-iles
# Processing Record 7 of Set 6 | pengcheng
# Processing Record 8 of Set 6 | shambu
# Processing Record 9 of Set 6 | bestobe
# Processing Record 10 of Set 6 | cardston
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | bella vista
# Processing Record 13 of Set 6 | along
# Processing Record 14 of Set 6 | padang
# Processing Record 15 of Set 6 | quatre cocos
# Processing Record 16 of Set 6 | celestun
# Processing Record 17 of Set 6 | nakamura
# Processing Record 18 of Set 6 | clyde river
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 6 | bambanglipuro
# Processing Record 22 of Set 6 | shache
# Processing Record 23 of Set 6 | wagar
# Processing Record 24 of Set 6 | guerrero negro
# Processing Record 25 of Set 6 | buraydah
# Processing Record 26 of Set 6 | port moresby
# Processing Record 27 of Set 6 | forbes
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 6 | marigot
# Processing Record 31 of Set 6 | luwuk
# Processing Record 32 of Set 6 | chicama
# Processing Record 33 of Set 6 | pueblo nuevo
# Processing Record 34 of Set 6 | daru
# Processing Record 35 of Set 6 | makueni
# Processing Record 36 of Set 6 | villefranche-sur-saone
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | souillac
# Processing Record 39 of Set 6 | krasnoselkup
# Processing Record 40 of Set 6 | cap malheureux
# Processing Record 41 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 42 of Set 6 | mandera
# Processing Record 43 of Set 6 | varhaug
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | chiang khong
# Processing Record 46 of Set 6 | mecca
# Processing Record 47 of Set 6 | akdepe
# Processing Record 48 of Set 6 | thompson
# Processing Record 49 of Set 6 | vila franca do campo
# Processing Record 50 of Set 6 | novikovo
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | alexandria
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | gushikawa
# Processing Record 5 of Set 7 | cherskiy
# Processing Record 6 of Set 7 | brae
# Processing Record 7 of Set 7 | angol
# Processing Record 8 of Set 7 | maceio
# Processing Record 9 of Set 7 | kutum
# Processing Record 10 of Set 7 | presidencia roque saenz pena
# Processing Record 11 of Set 7 | margate
# Processing Record 12 of Set 7 | aklavik
# Processing Record 13 of Set 7 | marzuq
# Processing Record 14 of Set 7 | ponta pora
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | tuy hoa
# Processing Record 35 of Set 8 | grindavik
# Processing Record 36 of Set 8 | batticaloa
# Processing Record 37 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 8 | huichapan
# Processing Record 39 of Set 8 | san policarpo
# Processing Record 40 of Set 8 | mont-de-marsan
# Processing Record 41 of Set 8 | barcelos
# Processing Record 42 of Set 8 | tabou
# Processing Record 43 of Set 8 | lantawan
# Processing Record 44 of Set 8 | leshukonskoye
# Processing Record 45 of Set 8 | fuerte olimpo
# Processing Record 46 of Set 8 | karaton
# Processing Record 47 of Set 8 | panzhihua
# Processing Record 48 of Set 8 | iwanai
# Processing Record 49 of Set 8 | alofi
# Processing Record 50 of Set 8 | stavern
# Processing Record 1 of Set 9 | mincivan
# Processing Record 2 of Set 9 | lagos
# Processing Record 3 of Set 9 | ternate
# Processing Record 4 of Set 9 | akyab
# Processing Record 5 of Set 9 | saldanha
# Processing Record 6 of Set 9 | caucaia
# Processing Record 7 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 9 | newport
# Processing Record 9 of Set 9 | golden
# Processing Record 10 of Set 9 | turukhansk
# Processing Record 11 of Set 9 | teguise
# Processing Record 12 of Set 9 | havelock
# Processing Record 13 of Set 9 | luderitz
# Processing Record 14 of Set 9 | roma
# Processing Record 15 of Set 9 | half moon bay
# Processing Record 16 of Set 9 | maracaibo
# Processing Record 17 of Set 9 | binika
# Processing Record 18 of Set 9 | qujing
# Processing Record 19 of Set 9 | namatanai
# Processing Record 20 of Set 9 | atbasar
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 9 | salta
# Processing Record 24 of Set 9 | datong
# Processing Record 25 of Set 9 | innisfail
# Processing Record 26 of Set 9 | cururupu
# Processing Record 27 of Set 9 | saint george
# Processing Record 28 of Set 9 | labuhan
# Processing Record 29 of Set 9 | naze
# Processing Record 30 of Set 9 | broken hill
# Processing Record 31 of Set 9 | jalu
# Processing Record 32 of Set 9 | gladstone
# Processing Record 33 of Set 9 | spirit river
# Processing Record 34 of Set 9 | meulaboh
# Processing Record 35 of Set 9 | rush
# Processing Record 36 of Set 9 | erdenet
# Processing Record 37 of Set 9 | flinders
# Processing Record 38 of Set 9 | praia
# Processing Record 39 of Set 9 | viedma
# Processing Record 40 of Set 9 | ambon
# Processing Record 41 of Set 9 | huarmey
# Processing Record 42 of Set 9 | tuyen quang
# Processing Record 43 of Set 9 | abha
# Processing Record 44 of Set 9 | yaan
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 9 | pinawa
# Processing Record 48 of Set 9 | iberia
# Processing Record 49 of Set 9 | lagoa
# Processing Record 50 of Set 9 | makinsk
# Processing Record 1 of Set 10 | noyabrsk
# Processing Record 2 of Set 10 | gramoteino
# Processing Record 3 of Set 10 | kahului
# Processing Record 4 of Set 10 | lasem
# Processing Record 5 of Set 10 | norman wells
# Processing Record 6 of Set 10 | evanston
# Processing Record 7 of Set 10 | northam
# Processing Record 8 of Set 10 | sitka
# Processing Record 9 of Set 10 | ankazoabo
# Processing Record 10 of Set 10 | boyolangu
# Processing Record 11 of Set 10 | verkhnevilyuysk
# Processing Record 12 of Set 10 | azrow
# City not found. Skipping...
# Processing Record 13 of Set 10 | oil city
# Processing Record 14 of Set 10 | mamakan
# Processing Record 15 of Set 10 | kadoma
# Processing Record 16 of Set 10 | preobrazheniye
# Processing Record 17 of Set 10 | nicoya
# Processing Record 18 of Set 10 | batemans bay
# Processing Record 19 of Set 10 | zhoucheng
# Processing Record 20 of Set 10 | evensk
# Processing Record 21 of Set 10 | ruwi
# Processing Record 22 of Set 10 | maua
# Processing Record 23 of Set 10 | sao mateus do maranhao
# Processing Record 24 of Set 10 | saint-honore
# Processing Record 25 of Set 10 | lokosovo
# Processing Record 26 of Set 10 | mugur-aksy
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | muros
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | te anau
# Processing Record 31 of Set 10 | ostersund
# Processing Record 32 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 10 | levelland
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | birin
# Processing Record 36 of Set 10 | haifa
# Processing Record 37 of Set 10 | maniitsoq
# Processing Record 38 of Set 10 | tabory
# Processing Record 39 of Set 10 | los llanos de aridane
# Processing Record 40 of Set 10 | fort nelson
# Processing Record 41 of Set 10 | itarema
# Processing Record 42 of Set 10 | port shepstone
# Processing Record 43 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 44 of Set 10 | kamaishi
# Processing Record 45 of Set 10 | eydhafushi
# Processing Record 46 of Set 10 | tikaitnagar
# Processing Record 47 of Set 10 | la ronge
# Processing Record 48 of Set 10 | tambovka
# Processing Record 49 of Set 10 | port blair
# Processing Record 50 of Set 10 | gashua
# Processing Record 1 of Set 11 | pitimbu
# Processing Record 2 of Set 11 | bykovo
# Processing Record 3 of Set 11 | luanda
# Processing Record 4 of Set 11 | karakol
# Processing Record 5 of Set 11 | coos bay
# Processing Record 6 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 7 of Set 11 | hit
# Processing Record 8 of Set 11 | maracacume
# Processing Record 9 of Set 11 | dogondoutchi
# Processing Record 10 of Set 11 | sorong
# Processing Record 11 of Set 11 | balkhash
# Processing Record 12 of Set 11 | olga
# Processing Record 13 of Set 11 | kisangani
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | otane
# Processing Record 16 of Set 11 | bodrum
# Processing Record 17 of Set 11 | saint-paul
# Processing Record 18 of Set 11 | kahramanmaras
# Processing Record 19 of Set 11 | yelizovo
# Processing Record 20 of Set 11 | saint-georges
# Processing Record 21 of Set 11 | college
# Processing Record 22 of Set 11 | znamenskoye
# Processing Record 23 of Set 11 | tazovskiy
# Processing Record 24 of Set 11 | sasykoli
# Processing Record 25 of Set 11 | vardo
# Processing Record 26 of Set 11 | buala
# Processing Record 27 of Set 11 | talnakh
# Processing Record 28 of Set 11 | havre-saint-pierre
# Processing Record 29 of Set 11 | andenes
# Processing Record 30 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 11 | sungairaya
# Processing Record 32 of Set 11 | porto santo
# Processing Record 33 of Set 11 | yarada
# Processing Record 34 of Set 11 | xuddur
# Processing Record 35 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 11 | touros
# Processing Record 37 of Set 11 | bartica
# Processing Record 38 of Set 11 | apt
# Processing Record 39 of Set 11 | kailua
# Processing Record 40 of Set 11 | lincoln
# Processing Record 41 of Set 11 | charlestown
# Processing Record 42 of Set 11 | chernolesskoye
# Processing Record 43 of Set 11 | jalingo
# Processing Record 44 of Set 11 | beaupre
# Processing Record 45 of Set 11 | manta
# Processing Record 46 of Set 11 | kanashevo
# Processing Record 47 of Set 11 | cauquenes
# Processing Record 48 of Set 11 | parrita
# Processing Record 49 of Set 11 | jieshi
# Processing Record 50 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 1 of Set 12 | geraldton
# Processing Record 2 of Set 12 | antalaha
# Processing Record 3 of Set 12 | kununurra
# Processing Record 4 of Set 12 | dubai
# Processing Record 5 of Set 12 | kungurtug
# Processing Record 6 of Set 12 | hauterive
# Processing Record 7 of Set 12 | rabo de peixe
# Processing Record 8 of Set 12 | beberibe
# Processing Record 9 of Set 12 | emilio carranza
# Processing Record 10 of Set 12 | den helder
# Processing Record 11 of Set 12 | tapes
# Processing Record 12 of Set 12 | likhoslavl
# Processing Record 13 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 12 | jibuti
# Processing Record 15 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 16 of Set 12 | pithapuram
# Processing Record 17 of Set 12 | kirakira
# Processing Record 18 of Set 12 | adrar
# Processing Record 19 of Set 12 | lorengau
# Processing Record 20 of Set 12 | deming
# Processing Record 21 of Set 12 | kemijarvi
# Processing Record 22 of Set 12 | tomatlan
# Processing Record 23 of Set 12 | harper
# Processing Record 24 of Set 12 | blagoyevo
# Processing Record 25 of Set 12 | baherden
# Processing Record 26 of Set 12 | davidson
# Processing Record 27 of Set 12 | apozol
# Processing Record 28 of Set 12 | moindou
# Processing Record 29 of Set 12 | kampong thum
# Processing Record 30 of Set 12 | kerema
# Processing Record 31 of Set 12 | punta alta
# Processing Record 32 of Set 12 | antofagasta
# Processing Record 33 of Set 12 | seoul
# Processing Record 34 of Set 12 | juegang
# Processing Record 35 of Set 12 | sagay
# Processing Record 36 of Set 12 | biak
# Processing Record 37 of Set 12 | manga
# Processing Record 38 of Set 12 | mayumba
# Processing Record 39 of Set 12 | viking
# Processing Record 40 of Set 12 | santa marta
# Processing Record 41 of Set 12 | north bend
# Processing Record 42 of Set 12 | auki
# Processing Record 43 of Set 12 | dingle
# Processing Record 44 of Set 12 | tikapur
# Processing Record 45 of Set 12 | banff
# Processing Record 46 of Set 12 | koubia
# Processing Record 47 of Set 12 | poum
# Processing Record 48 of Set 12 | nizhnevartovsk
# Processing Record 49 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 12 | teeli
# Processing Record 1 of Set 13 | lexington
# Processing Record 2 of Set 13 | yulara
# Processing Record 3 of Set 13 | sorland
# Processing Record 4 of Set 13 | morant bay
# Processing Record 5 of Set 13 | cartagena
# Processing Record 6 of Set 13 | taiyuan
# Processing Record 7 of Set 13 | baykit
# Processing Record 8 of Set 13 | ottawa
# Processing Record 9 of Set 13 | elko
# Processing Record 10 of Set 13 | ljungby
# Processing Record 11 of Set 13 | nioro
# Processing Record 12 of Set 13 | karatau
# Processing Record 13 of Set 13 | victoria point
# Processing Record 14 of Set 13 | ordzhonikidze
# Processing Record 15 of Set 13 | yeppoon
# Processing Record 16 of Set 13 | san vicente
# Processing Record 17 of Set 13 | surt
# Processing Record 18 of Set 13 | zahnitkiv
# Processing Record 19 of Set 13 | sarakhs
# Processing Record 20 of Set 13 | ahipara
# Processing Record 21 of Set 13 | kuytun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
mintemp = float(input("Inform the minimum Temp preferable:"))
maxtemp = float(input("Inform the maximum Temp preferable:"))
# Out:
# Inform the minimum Temp preferable:200
# Inform the maximum Temp preferable:300

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
city_data_temp_df = city_data_df.loc[(city_data_df["Max Temp"] >= mintemp) & (city_data_df["Max Temp"] <= maxtemp)]
city_data_temp_df.isnull().sum()
clean_df = city_data_temp_df.dropna()
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}


for index, row in hotel_df.iterrows():

    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"

    
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    

    hotels = requests.get(url, params=params).json()
    
    try:
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found - Skip")
# Out:
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
clean_hotel_df=hotel_df[hotel_df["Hotel Name"].astype(bool)]

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    City_ID           City Country  Max Temp      Lat       Lng  \
# 0        0    Yellowknife      CA    265.44  62.4560 -114.3525
# 1        2         Lompoc      US    289.70  34.6391 -120.4579
# 2        3         Castro      BR    283.83 -24.7911  -50.0119
# 3        4        Mataura      NZ    289.53 -46.1927  168.8643
# 4        5  Mar Del Plata      AR    290.42 -38.0023  -57.5575
# 5        6   Krasnoselkup      RU    263.80  65.7000   82.4667
# 6        7          Kenai      US    280.39  60.5544 -151.2583
# 7        8        Rikitea      PF    298.97 -23.1203 -134.9692
# 8        9     Walvis Bay     NaN    284.68 -22.9575   14.5053
# 9       10    Tuktoyaktuk      CA    264.15  69.4541 -133.0374
#
#                                  Hotel Name
# 0                        The Explorer Hotel
# 1  Holiday Inn Express Lompoc, an IHG Hotel
# 2                            CHACARA BAILLY
# 3                             Ellie's Villa
# 4                  Gran Hotel Mar del Plata
# 5                 Krasnosel'kupnefteprodukt
# 6                Aspen Extended Stay Suites
# 7                           People ThankYou
# 8                     Oyster Box Guesthouse
# 9                      End of The Road Ltd.

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>Temp Max {Max Temp} °C</dd>
</dl>

"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]


clean_hotel_df = hotel_df[hotel_df["Hotel Name"].astype(bool)]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"]=="Avarua")]
vacation_end = vacation_df.loc[(vacation_df["City"]=="Avarua")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"]=="Jamestown")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"]=="Hermanus")] 
vacation_stop3 = vacation_df.loc[(vacation_df["City"]=="Kodiak")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
try:
    start = vacation_start[["Lat","Lng"]].to_numpy()[0]
    end = vacation_end[["Lat","Lng"]].to_numpy()[0]
    stop1 =vacation_stop1[["Lat","Lng"]].to_numpy()[0] 
    stop2 =vacation_stop2[["Lat","Lng"]].to_numpy()[0]
    stop3 =vacation_stop3[["Lat","Lng"]].to_numpy()[0]
except:
    pass

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
try:
    fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
    travel = gmaps.directions_layer(
            start, end, waypoints=[stop1,stop2,stop3],
            travel_mode="DRIVING")
except:
    fig.add_layer(travel)
    fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NIGHTM~1\AppData\Local\Temp/ipykernel_2184/4021745532.py in <module>
#       5     travel = gmaps.directions_layer(
# ----> 6             start, end, waypoints=[stop1,stop2,stop3],
#       7             travel_mode="DRIVING")
#
# NameError: name 'start' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# C:\Users\NIGHTM~1\AppData\Local\Temp/ipykernel_2184/4021745532.py in <module>
#       7             travel_mode="DRIVING")
#       8 except:
# ----> 9     fig.add_layer(travel)
#      10     fig
#
# NameError: name 'travel' is not defined

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID       City Country  Max Temp      Lat       Lng  \
# 0       41  Jamestown      US    274.27  42.0970  -79.2353
# 1       32   Hermanus      ZA    288.60 -34.4187   19.2345
# 2       59     Kodiak      US    277.88  57.7900 -152.4072
#
#                                       Hotel Name
# 0                 Hampton Inn & Suites Jamestown
# 1                     Misty Waves Boutique Hotel
# 2  Best Western Kodiak Inn And Convention Center

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>Temp Max {Max Temp} °C</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
travel_marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(travel_marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
