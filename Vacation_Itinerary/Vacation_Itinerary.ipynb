# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

#additional dependencies
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import API key
#from config import g_key
# %store -r g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
## ADDITIONAL CODE TO MAKE THINGS WORK 

#Running a code as the system facing issues on fetching the data
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
 #Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1  
import requests
#from config import weather_api_key
# %store -r weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key
url
print(cities)
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# chokurdakh ru
# galiwinku au
# sioux lookout ca
# rikitea pf
# vaini to
# puri in
# avarua ck
# kieta pg
# luangwa zm
# bandarbeyla so
# mehamn no
# hilo us
# gat ly
# yellowknife ca
# namatanai pg
# hermanus za
# vostok ru
# nanakuli us
# washington us
# namatanai pg
# severo-kurilsk ru
# zoersel be
# shalya ru
# busselton au
# hopkinsville us
# hamilton bm
# hovd mn
# belushya guba ru
# rikitea pf
# erenhot cn
# samusu ws
# fortuna us
# zherdevka ru
# pevek ru
# port alfred za
# hilo us
# kavieng pg
# mar del plata ar
# atuona pf
# matara lk
# bredasdorp za
# new norfolk au
# pontianak id
# samalaeulu ws
# lebu cl
# sesimbra pt
# kharian pk
# bonthe sl
# noumea nc
# namibe ao
# buzmeyin tm
# yumen cn
# belton us
# mar del plata ar
# mys shmidta ru
# thompson ca
# palabuhanratu id
# vao nc
# kavaratti in
# hithadhoo mv
# seoul kr
# arrecife es
# ouallam ne
# calderitas mx
# huilong cn
# alice springs au
# dikson ru
# aykhal ru
# hobart au
# hambantota lk
# cape town za
# requena pe
# mataura pf
# ushuaia ar
# bredasdorp za
# somanda tz
# okha ru
# alofi nu
# punta arenas cl
# albany au
# bolshaya chernigovka ru
# atherton au
# jamestown sh
# puerto ayora ec
# albany au
# barentsburg sj
# tuktoyaktuk ca
# halalo wf
# kapaa us
# hermanus za
# hilo us
# tsihombe mg
# bluff nz
# saldanha za
# iroquois falls ca
# kapaa us
# wulanhaote cn
# tidore id
# mataura pf
# pisco pe
# praxedis guerrero mx
# sisimiut gl
# chuy uy
# rikitea pf
# chokurdakh ru
# kapaa us
# hobart au
# honningsvag no
# boueni yt
# kruisfontein za
# mao td
# cayenne gf
# vaini to
# plettenberg bay za
# auburn us
# ponta do sol cv
# mataura pf
# chokurdakh ru
# souillac mu
# yulara au
# punta arenas cl
# teruel es
# kapaa us
# tashtyp ru
# nemuro jp
# butaritari ki
# camana pe
# vostok ru
# victoria sc
# bluff nz
# longonjo ao
# piacabucu br
# cape town za
# vaini to
# candido mendes br
# sao felix do xingu br
# tolstoy-yurt ru
# ribeira grande pt
# hermanus za
# mataura pf
# hilo us
 'sentyabrskiy', 'bethel', 'newton', 'cape coast', 'marcona', 'nome', 'egvekinot', 'hami', 'moba', 'oranjemund', 'abonnema', 'sitka', 'arvin', 'leticia', 'acari', 'tiksi', 'caravelas', 'airai', 'san joaquin', 'lompoc', 'hervey bay', 'balaipungut', 'palmer', 'cap malheureux', 'kautokeino', 'illoqqortoormiut', 'ekhabi', 'clyde river', 'batemans bay', 'ahipara', 'okhotsk', 'lanzhou', 'katsuura', 'kolosovka', 'santa fe', 'mosalsk', 'quelimane', 'figeac', 'pelaya', 'walvis bay', 'kununurra', 'praia', 'werda', 'adrar', 'axim', 'husavik', 'vernon', 'tadine', 'cockburn town', 'sechura', 'verkhnyaya toyma', 'wattegama', 'ancona', 'sterling', 'chapeltown', 'pala', 'maniitsoq', 'chumikan', 'leningradskiy', 'erice', 'turan', 'altay', 'grindavik', 'deputatskiy', 'qaanaaq', 'kedarnath', 'siderno', 'emilio carranza', 'mount gambier', 'ixtapa', 'celestun', 'khonuu', 'antoniny', 'san-pedro', 'hualmay', 'oktyabrskoye', 'pavlohrad', 'valparaiso', 'bengkulu', 'port blair', 'klaksvik', 'puro', 'tautira', 'ciudad bolivar', 'ahtopol', 'anupgarh', 'eskasem', 'astana', 'rancho palos verdes', 'vaitupu', 'lorengau', 'porto novo', 'karratha', 'panjwin', 'strezhevoy', 'koroni', 'manta', 'grants pass', 'haibowan', 'comodoro rivadavia', 'longyearbyen', 'moree', 'maine-soroa', 'svetlaya', 'puerto cortes', 'wheeling', 'vardo', 'camacha', 'opuwo', 'inhambane', 'kayes', 'tawang', 'cookeville', 'aitape', 'coos bay', 'kula', 'port hardy', 'brae', 'sorvag', 'los llanos de aridane', 'arman', 'mahebourg', 'faanui', 'zhuhai', 'bitung', 'rawannawi', 'carnarvon', 'sarangani', 'bayki ...
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 1 | sioux lookout
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | puri
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | kieta
# Processing Record 9 of Set 1 | luangwa
# Processing Record 10 of Set 1 | bandarbeyla
# Processing Record 11 of Set 1 | mehamn
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | gat
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | namatanai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | nanakuli
# Processing Record 19 of Set 1 | washington
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | zoersel
# Processing Record 22 of Set 1 | shalya
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | hopkinsville
# Processing Record 25 of Set 1 | hamilton
# Processing Record 26 of Set 1 | hovd
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record
# City not found. Skipping...
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 22 of Set 4 | price
# Processing Record 23 of Set 4 | malanville
# Processing Record 24 of Set 4 | liverpool
# Processing Record 25 of Set 4 | novikovo
# Processing Record 26 of Set 4 | necochea
# Processing Record 27 of Set 4 | seoni
# Processing Record 28 of Set 4 | marsa matruh
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | tasiilaq
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | saint-augustin
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | sao gabriel da cachoeira
# Processing Record 36 of Set 4 | salinas
# Processing Record 37 of Set 4 | panzhihua
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | melo
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | mormugao
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | newton
# Processing Record 46 of Set 4 | cape coast
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 4 | nome
# Processing Record 49 of Set 4 | egvekinot
# Processing Record 50 of Set 4 | hami
# Processing Record 1 of Set 5 | moba
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | abonnema
# Processing Record 4 of Set 5 | sitka
# Processing Record 5 of Set 5 | arvin
# Processing Record 6 of Set 5 | leticia
# Processing Record 7 of Set 5 | acari
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | san joaquin
# Processing Record 12 of Set 5 | lompoc
# Processing Record 13 of Set 5 | hervey bay
# Processing Record 14 of Set 5 | balaipungut
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | cap malheureux
# Processing Record 17 of Set 5 | kautokeino
# Processing Record 18 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 5 | ekhabi
# Processing Record 20 of Set 5 | clyde river
# Processing Record 21 of Set 5 | batemans bay
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | okhotsk
# Processing Record 24 of Set 5 | lanzhou
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | kolosovka
# Processing Record 27 of Set 5 | santa fe
# Processing Record 28 of Set 5 | mosalsk
# Processing Record 29 of Set 5 | quelimane
# Processing Record 30 of Set 5 | figeac
# Processing Record 31 of Set 5 | pelaya
# Processing Record 32 of Set 5 | walvis bay
# Processing Record 33 of Set 5 | kununurra
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | werda
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | vernon
# Processing Record 40 of Set 5 | tadine
# Processing Record 41 of Set 5 | cockburn town
# Processing Record 42 of Set 5 | sechura
# Processing Record 43 of Set 5 | verkhnyaya toyma
# Processing Record 44 of Set 5 | wattegama
# Processing Record 45 of Set 5 | ancona
# Processing Record 46 of Set 5 | sterling
# Processing Record 47 of Set 5 | chapeltown
# Processing Record 48 of Set 5 | pala
# Processing Record 49 of Set 5 | maniitsoq
# Processing Record 50 of Set 5 | chumikan
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | erice
# Processing Record 3 of Set 6 | turan
# Processing Record 4 of Set 6 | altay
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | qaanaaq
# Processing Record 8 of Set 6 | kedarnath
# City not found. Skipping...
# Processing Record 9 of Set 6 | siderno
# Processing Record 10 of Set 6 | emilio carranza
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | ixtapa
# Processing Record 13 of Set 6 | celestun
# Processing Record 14 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 6 | antoniny
# Processing Record 16 of Set 6 | san-pedro
# Processing Record 17 of Set 6 | hualmay
# Processing Record 18 of Set 6 | oktyabrskoye
# Processing Record 19 of Set 6 | pavlohrad
# Processing Record 20 of Set 6 | valparaiso
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | port blair
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | puro
# Processing Record 25 of Set 6 | tautira
# Processing Record 26 of Set 6 | ciudad bolivar
# Processing Record 27 of Set 6 | ahtopol
# Processing Record 28 of Set 6 | anupgarh
# Processing Record 29 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 6 | astana
# Processing Record 31 of Set 6 | rancho palos verdes
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | lorengau
# Processing Record 34 of Set 6 | porto novo
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | panjwin
# City not found. Skipping...
# Processing Record 37 of Set 6 | strezhevoy
# Processing Record 38 of Set 6 | koroni
# Processing Record 39 of Set 6 | manta
# Processing Record 40 of Set 6 | grants pass
# Processing Record 41 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | comodoro rivadavia
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | moree
# Processing Record 45 of Set 6 | maine-soroa
# Processing Record 46 of Set 6 | svetlaya
# Processing Record 47 of Set 6 | puerto cortes
# City not found. Skipping...
# Processing Record 48 of Set 6 | wheeling
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | camacha
# Processing Record 1 of Set 7 | opuwo
# Processing Record 2 of Set 7 | inhambane
# Processing Record 3 of Set 7 | kayes
# Processing Record 4 of Set 7 | tawang
# Processing Record 5 of Set 7 | cookeville
# Processing Record 6 of Set 7 | aitape
# Processing Record 7 of Set 7 | coos bay
# Processing Record 8 of Set 7 | kula
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | brae
# Processing Record 11 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 7 | los llanos de aridane
# Processing Record 13 of Set 7 | arman
# Processing Record 14 of Set 7 | mahebourg
# Processing Record 15 of Set 7 | faanui
# Processing Record 16 of Set 7 | zhuhai
# Processing Record 17 of Set 7 | bitung
# Processing Record 18 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 7 | carnarvon
# Processing Record 20 of Set 7 | sarangani
# Processing Record 21 of Set 7 | baykit
# Processing Record 22 of Set 7 | biu
# Processing Record 23 of Set 7 | eguia
# Processing Record 24 of Set 7 | bergerac
# Processing Record 25 of Set 7 | marawi
# Processing Record 26 of Set 7 | berlevag
# Processing Record 27 of Set 7 | bambamarca
# Processing Record 28 of Set 7 | wajir
# Processing Record 29 of Set 7 | bodo
# Processing Record 30 of Set 7 | nanortalik
# Processing Record 31 of Set 7 | chicama
# Processing Record 32 of Set 7 | chern
# Processing Record 33 of Set 7 | tessalit
# Processing Record 34 of Set 7 | shache
# Processing Record 35 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 7 | maldonado
# Processing Record 37 of Set 7 | khabary
# Processing Record 38 of Set 7 | dingle
# Processing Record 39 of Set 7 | ossora
# Processing Record 40 of Set 7 | havelock
# Processing Record 41 of Set 7 | sola
# Processing Record 42 of Set 7 | bisira
# Processing Record 43 of Set 7 | tucuman
# Processing Record 44 of Set 7 | half moon bay
# Processing Record 45 of Set 7 | ulaangom
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | kahului
# Processing Record 48 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 49 of Set 7 | fort nelson
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | odweyne
# Processing Record 3 of Set 8 | baglan
# Processing Record 4 of Set 8 | floro
# Processing Record 5 of Set 8 | breytovo
# Processing Record 6 of Set 8 | constitucion
# Processing Record 7 of Set 8 | beloha
# Processing Record 8 of Set 8 | joshimath
# Processing Record 9 of Set 8 | inuvik
# Processing Record 10 of Set 8 | sagua la grande
# Processing Record 11 of Set 8 | acapulco
# Processing Record 12 of Set 8 | vagur
# Processing Record 13 of Set 8 | uthal
# Processing Record 14 of Set 8 | baiyin
# Processing Record 15 of Set 8 | porto santo
# Processing Record 16 of Set 8 | baoding
# Processing Record 17 of Set 8 | aksum
# Processing Record 18 of Set 8 | fairbanks
# Processing Record 19 of Set 8 | kyren
# Processing Record 20 of Set 8 | lisakovsk
# Processing Record 21 of Set 8 | nishihara
# Processing Record 22 of Set 8 | georgetown
# Processing Record 23 of Set 8 | hermsdorf
# Processing Record 24 of Set 8 | la palma
# Processing Record 44 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 9 | hope
# Processing Record 46 of Set 9 | mochudi
# Processing Record 47 of Set 9 | foam lake
# Processing Record 48 of Set 9 | claremore
# Processing Record 49 of Set 9 | kassala
# Processing Record 50 of Set 9 | harper
# Processing Record 1 of Set 10 | torbay
# Processing Record 2 of Set 10 | dofteana
# Processing Record 3 of Set 10 | sayat
# Processing Record 4 of Set 10 | rock springs
# Processing Record 5 of Set 10 | san policarpo
# Processing Record 6 of Set 10 | san buenaventura
# Processing Record 7 of Set 10 | belaya gora
# Processing Record 8 of Set 10 | qurayyat
# Processing Record 9 of Set 10 | kichmengskiy gorodok
# Processing Record 10 of Set 10 | santa barbara
# Processing Record 11 of Set 10 | warangal
# Processing Record 12 of Set 10 | abu samrah
# Processing Record 13 of Set 10 | demyansk
# Processing Record 14 of Set 10 | port keats
# Processing Record 15 of Set 10 | yaring
# Processing Record 16 of Set 10 | lavrentiya
# Processing Record 17 of Set 10 | ostrovnoy
# Processing Record 18 of Set 10 | yenagoa
# Processing Record 19 of Set 10 | oudtshoorn
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | vsetaty
# Processing Record 22 of Set 10 | ramnagar
# Processing Record 23 of Set 10 | mount pleasant
# Processing Record 24 of Set 10 | kawhia
# Processing Record 25 of Set 10 | dire
# Processing Record 26 of Set 10 | tikapur
# Processing Record 27 of Set 10 | chama
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | petervasara
# Processing Record 30 of Set 10 | anadyr
# Processing Record 31 of Set 10 | inta
# Processing Record 32 of Set 10 | wajid
# Processing Record 33 of Set 10 | ruteng
# Processing Record 34 of Set 10 | lebanon
# Processing Record 35 of Set 10 | zlitan
# Processing Record 36 of Set 10 | ternate
# Processing Record 37 of Set 10 | halkirk
# Processing Record 38 of Set 10 | baltay
# Processing Record 39 of Set 10 | sovetskiy
# Processing Record 40 of Set 10 | novoselitskoye
# Processing Record 41 of Set 10 | deming
# Processing Record 42 of Set 10 | carnot
# Processing Record 43 of Set 10 | manuk mangkaw
# Processing Record 44 of Set 10 | rundu
# Processing Record 45 of Set 10 | leh
# Processing Record 46 of Set 10 | pangoa
# Processing Record 47 of Set 10 | talnakh
# Processing Record 48 of Set 10 | key west
# Processing Record 49 of Set 10 | machali
# Processing Record 50 of Set 10 | gaoual
# Processing Record 1 of Set 11 | yatou
# Processing Record 2 of Set 11 | pokhara
# Processing Record 3 of Set 11 | pandan
# Processing Record 4 of Set 11 | aras
# Processing Record 5 of Set 11 | tyret pervaya
# Processing Record 6 of Set 11 | bayan
# Processing Record 7 of Set 11 | nouakchott
# Processing Record 8 of Set 11 | asau
# Processing Record 9 of Set 11 | la ronge
# Processing Record 10 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 11 | jinka
# Processing Record 13 of Set 11 | ulladulla
# Processing Record 14 of Set 11 | puerto narino
# Processing Record 15 of Set 11 | nortelandia
# Processing Record 16 of Set 11 | zhezkazgan
# Processing Record 17 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 11 | katherine
# Processing Record 19 of Set 11 | huntsville
# Processing Record 20 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 21 of Set 11 | angra
# City not found. Skipping...
# Processing Record 22 of Set 11 | senneterre
# Processing Record 23 of Set 11 | arcata
# Processing Record 24 of Set 11 | avera
# Processing Record 25 of Set 11 | yoichi
# Processing Record 26 of Set 11 | guerrero negro
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | port hawkesbury
# Processing Record 29 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 11 | garowe
# Processing Record 31 of Set 11 | kondinskoye
# Processing Record 32 of Set 11 | verkhnevilyuysk
# Processing Record 33 of Set 11 | dumai
# Processing Record 34 of Set 11 | ostersund
# Processing Record 35 of Set 11 | tahe
# Processing Record 36 of Set 11 | alta floresta
# Processing Record 37 of Set 11 | channel-port aux basques
# Processing Record 38 of Set 11 | baton rouge
# Processing Record 39 of Set 11 | uruzgan
# Processing Record 40 of Set 11 | nova olimpia
# Processing Record 41 of Set 11 | naze
# Processing Record 42 of Set 11 | sandpoint
# Processing Record 43 of Set 11 | kiunga
# Processing Record 44 of Set 11 | sao joao da barra
# Processing Record 45 of Set 11 | meulaboh
# Processing Record 46 of Set 11 | cervo
# Processing Record 47 of Set 11 | majene
# Processing Record 48 of Set 11 | ambilobe
# Processing Record 49 of Set 11 | savino
# Processing Record 50 of Set 11 | eureka
# Processing Record 1 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 12 | glebychevo
# Processing Record 3 of Set 12 | umm lajj
# Processing Record 4 of Set 12 | morondava
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | alnavar
# Processing Record 7 of Set 12 | abnub
# Processing Record 8 of Set 12 | beringovskiy
# Processing Record 9 of Set 12 | lewiston
# Processing Record 10 of Set 12 | cerrito
# Processing Record 11 of Set 12 | dongying
# Processing Record 12 of Set 12 | mayumba
# Processing Record 13 of Set 12 | zaranj
# Processing Record 14 of Set 12 | faya
# Processing Record 15 of Set 12 | luba
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | igarka
# Processing Record 18 of Set 12 | cap-chat
# Processing Record 19 of Set 12 | marystown
# Processing Record 20 of Set 12 | tra vinh
# Processing Record 21 of Set 12 | aklavik
# Processing Record 22 of Set 12 | springbok
# Processing Record 23 of Set 12 | richards bay
# Processing Record 24 of Set 12 | maarianhamina
# Processing Record 25 of Set 12 | puerto rico
# Processing Record 26 of Set 12 | merauke
# Processing Record 27 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 12 | bunia
# Processing Record 29 of Set 12 | pouembout
# Processing Record 30 of Set 12 | sfantu gheorghe
# Processing Record 31 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 32 of Set 12 | zhigansk
# Processing Record 33 of Set 12 | santiago
# Processing Record 34 of Set 12 | pirovskoye
# Processing Record 35 of Set 12 | chopinzinho
# Processing Record 36 of Set 12 | catuday
# Processing Record 37 of Set 12 | culfa
# Processing Record 38 of Set 12 | tortoli
# Processing Record 39 of Set 12 | touros
# Processing Record 40 of Set 12 | zambezi
# Processing Record 41 of Set 12 | ust-kuyga
# Processing Record 42 of Set 12 | san cristobal
# Processing Record 43 of Set 12 | bulgan
# Processing Record 44 of Set 12 | great yarmouth
# Processing Record 45 of Set 12 | tomatlan
# Processing Record 46 of Set 12 | loandjili
# Processing Record 47 of Set 12 | vicuna
# Processing Record 48 of Set 12 | komsomolskiy
# Processing Record 49 of Set 12 | dvorichna
# Processing Record 50 of Set 12 | yafran
# Processing Record 1 of Set 13 | yegros
# Processing Record 2 of Set 13 | bhind
# Processing Record 3 of Set 13 | bacungan
# Processing Record 4 of Set 13 | stephenville
# Processing Record 5 of Set 13 | delano
# Processing Record 6 of Set 13 | krasnozerskoye
# Processing Record 7 of Set 13 | bria
# Processing Record 8 of Set 13 | clarence town
# Processing Record 9 of Set 13 | beidao
# Processing Record 10 of Set 13 | gayny
# Processing Record 11 of Set 13 | gunjur
# Processing Record 12 of Set 13 | ati
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
mintemp = float(input("Inform the minimum Temp preferable:"))
maxtemp = float(input("Inform the maximum Temp preferable:"))
# Out:
# Inform the minimum Temp preferable:200
# Inform the maximum Temp preferable:300

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
city_data_temp_df = city_data_df.loc[(city_data_df["Max Temp"] >= mintemp) & (city_data_df["Max Temp"] <= maxtemp)]
city_data_temp_df.isnull().sum()
clean_df = city_data_temp_df.dropna()
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}


for index, row in hotel_df.iterrows():

    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"

    
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    

    hotels = requests.get(url, params=params).json()
    
    try:
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found - Skip")
# Out:
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip

# %%
##ADDITIONAL CODE TO MAKE THINGS WORK
clean_hotel_df=hotel_df[hotel_df["Hotel Name"].astype(bool)]

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    City_ID          City Country  Max Temp      Lat       Lng  \
# 0        0       Wanning      CN    297.54  18.8003  110.3967
# 1        1    Bredasdorp      ZA    288.92 -34.5322   20.0403
# 2        2        Avarua      CK    297.18 -21.2078 -159.7750
# 3        3          Hilo      US    296.64  19.7297 -155.0900
# 4        4  Saint George      US    294.50  37.1041 -113.5841
# 5        5        Kodiak      US    275.98  57.7900 -152.4072
# 6        6       Mataura      NZ    276.19 -46.1927  168.8643
# 7        8     Jamestown      US    277.60  42.0970  -79.2353
# 8       11      Hermanus      ZA    290.82 -34.4187   19.2345
# 9       12  Punta Arenas      CL    281.21 -53.1500  -70.9167
#
#                                       Hotel Name
# 0                                 Paradise Hotel
# 1                       Bredasdorp Country Manor
# 2                                   Paradise Inn
# 3                            Hilo Hawaiian Hotel
# 4                    Best Western Plus Abbey Inn
# 5  Best Western Kodiak Inn And Convention Center
# 6                                  Ellie's Villa
# 7                 Hampton Inn & Suites Jamestown
# 8                     Misty Waves Boutique Hotel
# 9                                     Hotel Hain

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>Temp Max {Max Temp} °C</dd>
</dl>

"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]


clean_hotel_df = hotel_df[hotel_df["Hotel Name"].astype(bool)]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"]=="Avarua")]
vacation_end = vacation_df.loc[(vacation_df["City"]=="Avarua")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"]=="Jamestown")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"]=="Hermanus")] 
vacation_stop3 = vacation_df.loc[(vacation_df["City"]=="Kodiak")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat","Lng"]].to_numpy()[0]
end = vacation_end[["Lat","Lng"]].to_numpy()[0]
stop1 =vacation_stop1[["Lat","Lng"]].to_numpy()[0] 
stop2 =vacation_stop2[["Lat","Lng"]].to_numpy()[0]
stop3 =vacation_stop3[["Lat","Lng"]].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
travel= gmaps.directions_layer(
        start, end, waypoints=[stop1,stop2,stop3],
        travel_mode="DRIVING")
fig.add_layer(travel)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID       City Country  Max Temp      Lat       Lng  \
# 0        2     Avarua      CK    297.18 -21.2078 -159.7750
# 1        8  Jamestown      US    277.60  42.0970  -79.2353
# 2       11   Hermanus      ZA    290.82 -34.4187   19.2345
# 3        5     Kodiak      US    275.98  57.7900 -152.4072
#
#                                       Hotel Name
# 0                                   Paradise Inn
# 1                 Hampton Inn & Suites Jamestown
# 2                     Misty Waves Boutique Hotel
# 3  Best Western Kodiak Inn And Convention Center

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>Temp Max {Max Temp} °C</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
travel_marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(travel_marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
