# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

#extra dependency addition
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy


# Import API key
#from config import g_key
# %store -r g_key
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
#Running a code as the system facing issues on fetching the data
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
 #Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1  
import requests
#from config import weather_api_key
# %store -r weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key
url
print(cities)
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# yellowknife ca
# thio nc
# lompoc us
# castro cl
# mataura pf
# mar del plata ar
# krasnoselkup ru
# yellowknife ca
# kenai us
# rikitea pf
# cagayan de tawi-tawi ph
# walvis bay na
# tuktoyaktuk ca
# ca mau vn
# turan ru
# talcahuano cl
# kapaa us
# arraial do cabo br
# sept-iles ca
# castro cl
# hobart au
# bambous virieux mu
# half moon bay us
# hobyo so
# chuy uy
# mataura pf
# albany au
# gizo sb
# new norfolk au
# new norfolk au
# bluff nz
# mataura pf
# hilo us
# khatanga ru
# kushiro jp
# mar del plata ar
# hilo us
# dikson ru
# byron bay au
# jaisalmer in
# hermanus za
# larap ph
# prince rupert ca
# rikitea pf
# lebu cl
# grafenau de
# sola vu
# solnechnyy ru
# denpasar id
# geraldton au
# jamestown sh
# albany au
# albany au
# mataura pf
# ponta do sol cv
# bengkulu id
# ponta do sol cv
# provideniya ru
# valparaiso cl
# ushuaia ar
# tasiilaq gl
# sharjah ae
# ketchikan us
# mataura pf
# dikson ru
# tete mz
# albany au
# ushuaia ar
# saldanha za
# iqaluit ca
# kuche cn
# kameno bg
# airai pw
# taolanaro mg
# pevek ru
# butaritari ki
# hamilton bm
# nenjiang cn
# kodiak us
# dunedin nz
# hofn is
# qaanaaq gl
# severo-kurilsk ru
# tete mz
# lorengau pg
# ushuaia ar
# esperance au
# albany au
# comodoro rivadavia ar
# port said eg
# pevek ru
# boyolangu id
# attawapiskat ca
# bluff nz
# chokurdakh ru
# mbandaka cd
# new norfolk au
# senmonorom kh
# tiksi ru
# saint-philippe re
# jamestown sh
# albany au
# mys shmidta ru
# kavaratti in
# lahaina us
# longyearbyen sj
# neuquen ar
# we nc
# calabar ng
# pousat kh
# rungata ki
# qaanaaq gl
# port alfred za
# kapaa us
# punta arenas cl
# cape town za
# isshiki jp
# ornskoldsvik se
# castro cl
# berdigestyakh ru
# bairiki ki
# rikitea pf
# bredasdorp za
# garden city us
# gurgan az
# dikson ru
# lorengau pg
# bukama cd
# ushuaia ar
# metro id
# faanui pf
# mar del plata ar
# romitan uz
# taltal cl
# yumen cn
# cape town za
# hilo us
# anqing cn
# biak id
# say ne
# jamestown sh
# lasa cn
# vaini to
# saskylakh ru
# rikitea pf
# cape town za
# taolanaro mg
# nyagan ru
# cape town za
# qaanaaq gl
# saint george bm
# senekal za
# albany au
# bredasdorp za
# longyearbyen sj
# sitka us
# hermanus za
# rikitea pf
# nikolskoye ru
# grand-santi gf
# grootfontein na
# hilo us
# laguna br
# ushuaia ar
# puerto ayora ec
# busselton au
# kapoeta sd
# mount pleasant us
# piatra soimului ro
# touros br
# grand gaube mu
# alotau pg
# albany au
# qaanaaq gl
# hobart au
# chernyshevsk ru
# flinders au
# busselton au
# mercedes ar
# saint-philippe re
# okhotsk ru
# tramandai br
# port alfred za
# hermanus za
# mar del plata ar
# ushuaia ar
# fortuna us
# port lincoln au
# new norfolk au
# port elizabeth za
# popondetta pg
# mahebourg mu
# haibowan cn
# qaanaaq gl
# otautau nz
# kapaa us
# bengkulu id
# port moresby pg
# rura in
# cabo san lucas mx
# issoire fr
# victoria sc
# punta arenas cl
# hihifo to
# busselton au
# ribeira grande pt
# yellowknife ca
# yellowknife ca
# ingham au
# gambiran id
# half moon bay us
# seoul kr
# awjilah ly
# damara cf
# taolanaro mg
# barrow us
# mataura pf
# saint-francois gp
# grand river south east mu
# broome au
# isangel vu
# tondano id
# katsuura jp
# bethel us
# port alfred za
# provideniya ru
# matara lk
# ushuaia ar
# bluff nz
# pringsewu id
# carnarvon au
# belushya guba ru
# hofn is
# punta arenas cl
# nizhniy tsasuchey ru
# maloshuyka ru
# upernavik gl
# jamestown sh
# kirakira sb
# bluff nz
# cayenne gf
# busselton au
# talnakh ru
# amalapuram in
# sajanan tn
# jamestown sh
# bubaque gw
# rikitea pf
# kruisfontein za
# geraldton au
# shimoda jp
# byron bay au
# mataura pf
# hasaki jp
# nome us
# marystown ca
# kaitangata nz
# saleaula ws
# saleaula ws
# cabo san lucas mx
# avarua ck
# namibe ao
# punta arenas cl
# chimbote pe
# kavieng pg
# harper lr
# hermanus za
# clyde river ca
# bandarban bd
# vaini to
# rikitea pf
# taolanaro mg
# tautira pf
# hamilton bm
# nikolskoye ru
# rikitea pf
# evensk ru
# codrington ag
# mataura pf
# garden city us
# mahebourg mu
# khatanga ru
# qaanaaq gl
# goksun tr
# khatanga ru
# ankpa ng
# clyde river ca
# yellowknife ca
# barrow us
# grindavik is
# sakaiminato jp
# bredasdorp za
# ushuaia ar
# qaanaaq gl
# ponta do sol pt
# rikitea pf
# liverpool ca
# bluff nz
# cape town za
# ostrovnoy ru
# kurilsk ru
# bairiki ki
# nishihara jp
# riyadh sa
# busselton au
# la quinta us
# jamestown sh
# ribeira grande pt
# comodoro rivadavia ar
# nabire id
# puerto ayora ec
# balaipungut id
# motygino ru
# muros es
# benjamin aceval py
# punta arenas cl
# port elizabeth za
# saint-philippe re
# faanui pf
# guerrero negro mx
# ushuaia ar
# makaryev ru
# bredasdorp za
# albany au
# fortuna us
# busselton au
# mahebourg mu
# yellowknife ca
# altay cn
# ambilobe mg
# new norfolk au
# boyolangu id
# salalah om
# lorengau pg
# bredasdorp za
# butaritari ki
# abong mbang cm
# hithadhoo mv
# castro cl
# inhambane mz
# bengkulu id
# voloshka ru
# haines junction ca
# naze jp
# coruripe br
# constitucion mx
# hermanus za
# dukat ru
# punta arenas cl
# rikitea pf
# port moresby pg
# georgetown sh
# port keats au
# busselton au
# longyearbyen sj
# albany au
# port-gentil ga
# umzimvubu za
# ancud cl
# kalang ph
# calarca co
# busselton au
# busselton au
# hermanus za
# port alfred za
# las matas de farfan do
# sayyan ye
# bentiu sd
# tilichiki ru
# avarua ck
# khatanga ru
# kapaa us
# pervomayskiy ru
# isangel vu
# ponta do sol cv
# carutapera br
# hobart au
# bubaque gw
# belushya guba ru
# thompson ca
# kavieng pg
# hofn is
# lebu cl
# mataura pf
# qaanaaq gl
# hilo us
# mogadishu so
# hasaki jp
# port alfred za
# urucara br
# albany au
# vallenar cl
# celendin pe
# punta arenas cl
# jamestown sh
# mstera ru
# tanabe jp
# avarua ck
# nikolskoye ru
# mataura pf
# chagda ru
# palabuhanratu id
# jamestown sh
# grand river south east mu
# urdoma ru
# albany au
# steyr at
# puerto baquerizo moreno ec
# busselton au
# borazjan ir
# butaritari ki
# broken hill au
# severo-kurilsk ru
# kapaa us
# sao filipe cv
# dikson ru
# ushuaia ar
# thompson ca
# busselton au
# busselton au
# puerto ayora ec
# reidsville us
# kodiak us
# walvis bay na
# busselton au
# east london za
# attawapiskat ca
# road town vg
# saint-philippe re
# khormuj ir
# vaini to
# pisco pe
# belmonte br
# belushya guba ru
# dikson ru
# hofn is
# aiken us
# tiksi ru
# taybad ir
# punta arenas cl
# mopipi bw
# buxton us
# cabo san lucas mx
# thompson ca
# mataura pf
# avarua ck
# rikitea pf
# ginda er
# constitucion cl
# ryotsu jp
# batagay-alyta ru
# portland au
# amderma ru
# illoqqortoormiut gl
# ushuaia ar
# katsuura jp
# hilo us
# attawapiskat ca
# tasiilaq gl
# east london za
# port alfred za
# avarua ck
# hofn is
# nome us
# albany au
# clyde river ca
# kapaa us
# tasiilaq gl
# upernavik gl
# rikitea pf
# barentsburg sj
# rassvet ru
# puerto ayora ec
# hobart au
# krasnyy kommunar ru
# atuona pf
# ushuaia ar
# longyearbyen sj
# yunjinghong cn
# busselton au
# bredasdorp za
# morro bay us
# ushuaia ar
# hermanus za
# abu dhabi ae
# busselton au
# abu samrah qa
# taolanaro mg
# punta arenas cl
# vaini to
# samusu ws
# hobart au
# kintinku tz
# port lincoln au
# cabo san lucas mx
# shingu jp
# nome us
# tuktoyaktuk ca
# puerto ayora ec
# kuche cn
# varazdin hr
# isangel vu
# ushuaia ar
# bathsheba bb
# pitsunda ge
# new norfolk au
# nybro se
# south venice us
# hvolsvollur is
# goure ne
# matara lk
# belushya guba ru
# vestmannaeyjar is
# sitka us
# mossendjo cg
# zhigalovo ru
# woodward us
# rikitea pf
# bethel us
# fortuna us
# provideniya ru
# bulgan mn
# hobart au
# busselton au
# terney ru
# port alfred za
# mataura pf
# punta arenas cl
# punta arenas cl
# skjaerhollen no
# hualmay pe
# cairns au
# luderitz na
 'carballo', 'catamarca', 'tsihombe', 'ituni', 'ayan', 'bethel', 'hirara', 'talnakh', 'coari', 'esmeraldas', 'mentok', 'soyo', 'narasannapeta', 'rocky mountain house', 'ambilobe', 'tautira', 'barentsburg', 'cherskiy', 'tuy hoa', 'anthia', 'iquitos', 'taoudenni', 'isangel', 'abu samrah', 'zhirnovsk', 'dajal', 'manzhouli', 'tecolutla', 'gamba', 'juneau', 'grindavik', 'ancud', 'seredka', 'tubay', 'brae', 'gorin', 'upernavik', 'college', 'victoria', 'los arabos', 'bismarck', 'tres pontas', 'santiago', 'poplar bluff', 'iralaya', 'jaque', 'riyadh', 'cravo norte', 'itoman', 'talara', 'goderich', 'markova', 'ambositra', 'lolua', 'viligili', 'sandpoint', 'mormugao', 'little current', 'los llanos de aridane', 'lagoa', 'imbituba', 'sioux lookout', 'port-gentil', 'beni suef', 'alofi', 'verkhnyaya inta', 'tiznit', 'vardo', 'kruisfontein', 'jinchengjiang', 'arman', 'saint-georges', 'coquimbo', 'verkhnedneprovskiy', 'trairi', 'zhigansk', 'algiers', 'ola', 'eldikan', 'khani', 'ribeira grande', 'igarape-acu', 'blackwater', 'catabola', 'namatanai', 'saurimo', 'saleaula', 'rabo de peixe', 'lingyuan', 'cabo san lucas', 'constitucion', 'manbij', 'schleswig', 'chiredzi', 'ponta pora', 'eureka', 'lilongwe', 'bratislava', 'the valley', 'port shepstone', 'miki', 'nyagan', 'saint george', 'senekal', 'sitka', 'grand-santi', 'grootfontein', 'laguna', 'kapoeta', 'mount pleasant', 'piatra soimului', 'touros', 'alotau', 'chernyshevsk', 'flinders', 'mercedes', 'okhotsk', 'tramandai', 'fortuna', 'port lincoln', ' ...
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | thio
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | krasnoselkup
# Processing Record 8 of Set 1 | kenai
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 1 | walvis bay
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | ca mau
# Processing Record 14 of Set 1 | turan
# Processing Record 15 of Set 1 | talcahuano
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | sept-iles
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | half moon bay
# Processing Record 22 of Set 1 | hobyo
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | gizo
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | kushiro
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | byron bay
# Processing Record 33 of Set 1 | jaisalmer
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | larap
# Processing Record 36 of Set 1 | prince rupert
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | grafenau
# Processing Record 39 of Set 1 | sola
# Processing Record 40 of Set 1 | solnechnyy
# Processing Record 41 of Set 1 | denpasar
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | valparaiso
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | sharjah
# Processing Record 1 of Set 2 | ketchikan
# Processing Record 2 of Set 2 | tete
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 2 | kameno
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | hamilton
# Processing Record 12 of Set 2 | nenjiang
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | port said
# Processing Record 22 of Set 2 | boyolangu
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | mbandaka
# Processing Record 26 of Set 2 | senmonorom
# City not found. Skipping...
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | lahaina
# Processing Record 32 of Set 2 | longyearbyen
# Processing Record 33 of Set 2 | neuquen
# Processing Record 34 of Set 2 | we
# City not found. Skipping...
# Processing Record 35 of Set 2 | calabar
# Processing Record 36 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | isshiki
# City not found. Skipping...
# Processing Record 42 of Set 2 | ornskoldsvik
# Processing Record 43 of Set 2 | berdigestyakh
# Processing Record 44 of Set 2 | bairiki
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | garden city
# Processing Record 47 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 48 of Set 2 | bukama
# Processing Record 49 of Set 2 | metro
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | romitan
# Processing Record 2 of Set 3 | taltal
# Processing Record 3 of Set 3 | yumen
# Processing Record 4 of Set 3 | anqing
# Processing Record 5 of Set 3 | biak
# Processing Record 6 of Set 3 | say
# Processing Record 7 of Set 3 | lasa
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | obihiro
# Processing Record 11 of Set 3 | sabzevar
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | monterey
# Processing Record 15 of Set 3 | ohara
# Processing Record 16 of Set 3 | jalu
# Processing Record 17 of Set 3 | praya
# Processing Record 18 of Set 3 | sovetskiy
# Processing Record 19 of Set 3 | goiatuba
# Processing Record 20 of Set 3 | salalah
# Processing Record 21 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 3 | trincomalee
# Processing Record 23 of Set 3 | salta
# Processing Record 24 of Set 3 | hongjiang
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 3 | sinnamary
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | itarema
# Processing Record 30 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 3 | kuningan
# Processing Record 32 of Set 3 | mitsamiouli
# Processing Record 33 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | makakilo city
# Processing Record 37 of Set 3 | houma
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | erzin
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | antequera
# Processing Record 42 of Set 3 | buala
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | ylivieska
# Processing Record 45 of Set 3 | marsa matruh
# Processing Record 46 of Set 3 | zhetybay
# City not found. Skipping...
# Processing Record 47 of Set 3 | manokwari
# Processing Record 48 of Set 3 | faya
# Processing Record 49 of Set 3 | cairns
# Processing Record 50 of Set 3 | antofagasta
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | filadelfia
# Processing Record 3 of Set 4 | husavik
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | la ronge
# Processing Record 6 of Set 4 | dongsheng
# Processing Record 7 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 4 | nicoya
# Processing Record 9 of Set 4 | willowmore
# Processing Record 10 of Set 4 | kandrian
# Processing Record 11 of Set 4 | griffith
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | busselton
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | oistins
# Processing Record 16 of Set 4 | ust-nera
# Processing Record 17 of Set 4 | moree
# Processing Record 18 of Set 4 | bonavista
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | donskoye
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | baiyin
# Processing Record 23 of Set 4 | caceres
# Processing Record 24 of Set 4 | del rio
# Processing Record 25 of Set 4 | shache
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | tabou
# Processing Record 28 of Set 4 | margate
# Processing Record 29 of Set 4 | port augusta
# Processing Record 30 of Set 4 | tomatlan
# Processing Record 31 of Set 4 | rio gallegos
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | kirensk
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | dingle
# Processing Record 37 of Set 4 | grand gaube
# Processing Record 38 of Set 4 | azul
# Processing Record 39 of Set 4 | udala
# Processing Record 40 of Set 4 | amagi
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | nyurba
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | chiang klang
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | chapais
# Processing Record 47 of Set 4 | sobolevo
# Processing Record 48 of Set 4 | jamsa
# Processing Record 49 of Set 4 | hualmay
# Processing Record 50 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | kailua
# Processing Record 3 of Set 5 | inongo
# Processing Record 4 of Set 5 | alta floresta
# Processing Record 5 of Set 5 | ugoofaaru
# Processing Record 6 of Set 5 | carballo
# Processing Record 7 of Set 5 | catamarca
# Processing Record 8 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 5 | ayan
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | hirara
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | coari
# Processing Record 15 of Set 5 | esmeraldas
# Processing Record 16 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 5 | soyo
# Processing Record 18 of Set 5 | narasannapeta
# Processing Record 19 of Set 5 | rocky mountain house
# Processing Record 20 of Set 5 | ambilobe
# Processing Record 21 of Set 5 | tautira
# Processing Record 22 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | tuy hoa
# Processing Record 25 of Set 5 | anthia
# City not found. Skipping...
# Processing Record 26 of Set 5 | iquitos
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | abu samrah
# Processing Record 30 of Set 5 | zhirnovsk
# Processing Record 31 of Set 5 | dajal
# Processing Record 32 of Set 5 | manzhouli
# Processing Record 33 of Set 5 | tecolutla
# Processing Record 34 of Set 5 | gamba
# Processing Record 35 of Set 5 | juneau
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | seredka
# Processing Record 39 of Set 5 | tubay
# Processing Record 40 of Set 5 | brae
# Processing Record 41 of Set 5 | gorin
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | college
# Processing Record 44 of Set 5 | victoria
# Processing Record 45 of Set 5 | los arabos
# Processing Record 46 of Set 5 | bismarck
# Processing Record 47 of Set 5 | tres pontas
# Processing Record 48 of Set 5 | santiago
# Processing Record 49 of Set 5 | poplar bluff
# Processing Record 50 of Set 5 | iralaya
# Processing Record 1 of Set 6 | jaque
# Processing Record 2 of Set 6 | riyadh
# Processing Record 3 of Set 6 | cravo norte
# Processing Record 4 of Set 6 | itoman
# Processing Record 5 of Set 6 | talara
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | markova
# Processing Record 8 of Set 6 | ambositra
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 6 | sandpoint
# Processing Record 12 of Set 6 | mormugao
# Processing Record 13 of Set 6 | little current
# Processing Record 14 of Set 6 | los llanos de aridane
# Processing Record 15 of Set 6 | lagoa
# Processing Record 16 of Set 6 | imbituba
# Processing Record 17 of Set 6 | sioux lookout
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | beni suef
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | verkhnyaya inta
# Processing Record 22 of Set 6 | tiznit
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | kruisfontein
# Processing Record 25 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 26 of Set 6 | arman
# Processing Record 27 of Set 6 | saint-georges
# Processing Record 28 of Set 6 | coquimbo
# Processing Record 29 of Set 6 | verkhnedneprovskiy
# Processing Record 30 of Set 6 | trairi
# Processing Record 31 of Set 6 | zhigansk
# Processing Record 32 of Set 6 | algiers
# Processing Record 33 of Set 6 | ola
# Processing Record 34 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 6 | khani
# Processing Record 36 of Set 6 | ribeira grande
# Processing Record 37 of Set 6 | igarape-acu
# City not found. Skipping...
# Processing Record 38 of Set 6 | blackwater
# Processing Record 39 of Set 6 | catabola
# Processing Record 40 of Set 6 | namatanai
# Processing Record 41 of Set 6 | saurimo
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | rabo de peixe
# Processing Record 44 of Set 6 | lingyuan
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | constitucion
# Processing Record 47 of Set 6 | manbij
# Processing Record 48 of Set 6 | schleswig
# Processing Record 49 of Set 6 | chiredzi
# Processing Record 50 of Set 6 | ponta pora
# Processing Record 1 of Set 7 | eureka
# Processing Record 2 of Set 7 | lilongwe
# Processing Record 3 of Set 7 | bratislava
# Processing Record 4 of Set 7 | the valley
# Processing Record 5 of Set 7 | port shepstone
# Processing Record 6 of Set 7 | miki
# Processing Record 7 of Set 7 | nyagan
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | senekal
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | grand-santi
# Processing Record 12 of Set 7 | grootfontein
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | kapoeta
# Processing Record 15 of Set 7 | mount pleasant
# Processing Record 16 of Set 7 | piatra soimului
# Processing Record 17 of Set 7 | touros
# Processing Record 18 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 7 | chernyshevsk
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | mercedes
# Processing Record 22 of Set 7 | okhotsk
# Processing Record 23 of Set 7 | tramandai
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | popondetta
# Processing Record 27 of Set 7 | mahebourg
# Processing Record 28 of Set 7 | otautau
# Processing Record 29 of Set 7 | port moresby
# Processing Record 30 of Set 7 | rura
# Processing Record 31 of Set 7 | issoire
# Processing Record 32 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 7 | ingham
# Processing Record 34 of Set 7 | gambiran
# Processing Record 35 of Set 7 | seoul
# Processing Record 36 of Set 7 | awjilah
# Processing Record 37 of Set 7 | damara
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | tondano
# Processing Record 41 of Set 7 | katsuura
# Processing Record 42 of Set 7 | matara
# Processing Record 43 of Set 7 | pringsewu
# Processing Record 44 of Set 7 | nizhniy tsasuchey
# Processing Record 45 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 7 | kirakira
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | amalapuram
# Processing Record 49 of Set 7 | sajanan
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | shimoda
# Processing Record 2 of Set 8 | hasaki
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | marystown
# Processing Record 5 of Set 8 | kaitangata
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | chimbote
# Processing Record 8 of Set 8 | kavieng
# Processing Record 9 of Set 8 | harper
# Processing Record 10 of Set 8 | clyde river
# Processing Record 11 of Set 8 | bandarban
# Processing Record 12 of Set 8 | evensk
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | goksun
# Processing Record 15 of Set 8 | ankpa
# Processing Record 16 of Set 8 | sakaiminato
# Processing Record 17 of Set 8 | liverpool
# Processing Record 18 of Set 8 | ostrovnoy
# Processing Record 19 of Set 8 | kurilsk
# Processing Record 20 of Set 8 | nishihara
# Processing Record 21 of Set 8 | la quinta
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | balaipungut
# Processing Record 24 of Set 8 | motygino
# Processing Record 25 of Set 8 | muros
# Processing Record 26 of Set 8 | benjamin aceval
# Processing Record 27 of Set 8 | guerrero negro
# Processing Record 28 of Set 8 | makaryev
# Processing Record 29 of Set 8 | altay
# Processing Record 30 of Set 8 | abong mbang
# Processing Record 31 of Set 8 | sabang
# Processing Record 32 of Set 8 | waipawa
# Processing Record 33 of Set 8 | rudbar
# Processing Record 34 of Set 8 | copperas cove
# Processing Record 35 of Set 8 | kamenka
# Processing Record 36 of Set 8 | paamiut
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | gazanjyk
# Processing Record 39 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 8 | lisala
# Processing Record 41 of Set 8 | yangambi
# Processing Record 42 of Set 8 | praia da vitoria
# Processing Record 43 of Set 8 | eyl
# Processing Record 44 of Set 8 | east london
# Processing Record 45 of Set 8 | haselunne
# Processing Record 46 of Set 8 | quesnel
# Processing Record 47 of Set 8 | nemuro
# Processing Record 48 of Set 8 | tumpat
# Processing Record 49 of Set 8 | san carlos de bariloche
# Processing Record 50 of Set 8 | nokaneng
# Processing Record 1 of Set 9 | kulhudhuffushi
# Processing Record 2 of Set 9 | torbay
# Processing Record 3 of Set 9 | sotnikovskoye
# Processing Record 4 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 9 | nanchang
# Processing Record 6 of Set 9 | vallenar
# Processing Record 7 of Set 9 | itaituba
# Processing Record 8 of Set 9 | shingu
# Processing Record 9 of Set 9 | chaman
# Processing Record 10 of Set 9 | batticaloa
# Processing Record 11 of Set 9 | tucumcari
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | padang
# Processing Record 14 of Set 9 | verkhoyansk
# Processing Record 15 of Set 9 | tezu
# Processing Record 16 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 9 | alice springs
# Processing Record 18 of Set 9 | sao joao da barra
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | concordia
# Processing Record 21 of Set 9 | champasak
# Processing Record 22 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | aracati
# Processing Record 24 of Set 9 | paita
# Processing Record 25 of Set 9 | tukrah
# Processing Record 26 of Set 9 | lampa
# Processing Record 27 of Set 9 | sistranda
# Processing Record 28 of Set 9 | havoysund
# Processing Record 29 of Set 9 | te anau
# Processing Record 30 of Set 9 | patan
# Processing Record 31 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 9 | preobrazheniye
# Processing Record 33 of Set 9 | henties bay
# Processing Record 34 of Set 9 | bathsheba
# Processing Record 35 of Set 9 | barranca
# Processing Record 36 of Set 9 | kupino
# Processing Record 37 of Set 9 | orjahovo
# City not found. Skipping...
# Processing Record 38 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 9 | stulpicani
# Processing Record 40 of Set 9 | chino valley
# Processing Record 41 of Set 9 | norman wells
# Processing Record 42 of Set 9 | sendenhorst
# Processing Record 43 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 9 | lodja
# Processing Record 45 of Set 9 | pilar
# Processing Record 46 of Set 9 | tyup
# Processing Record 47 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 48 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | vostok
# Processing Record 50 of Set 9 | wilkie
# Processing Record 1 of Set 10 | trabzon
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | gombe
# Processing Record 4 of Set 10 | candelaria
# Processing Record 5 of Set 10 | takoradi
# Processing Record 6 of Set 10 | rudnogorsk
# Processing Record 7 of Set 10 | ewa beach
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | vila velha
# Processing Record 10 of Set 10 | daru
# Processing Record 11 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 10 | katiola
# Processing Record 13 of Set 10 | saint-joseph
# Processing Record 14 of Set 10 | vangaindrano
# Processing Record 15 of Set 10 | newport
# Processing Record 16 of Set 10 | tougue
# Processing Record 17 of Set 10 | sorong
# Processing Record 18 of Set 10 | saint-augustin
# Processing Record 19 of Set 10 | freetown
# Processing Record 20 of Set 10 | temozon
# Processing Record 21 of Set 10 | brigantine
# Processing Record 22 of Set 10 | aran
# Processing Record 23 of Set 10 | la asuncion
# Processing Record 24 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 25 of Set 10 | ballina
# Processing Record 26 of Set 10 | miraflores
# Processing Record 27 of Set 10 | mount gambier
# Processing Record 28 of Set 10 | koumac
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | la palma
# Processing Record 31 of Set 10 | nata
# Processing Record 32 of Set 10 | melfi
# Processing Record 33 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 10 | serenje
# Processing Record 35 of Set 10 | moron
# Processing Record 36 of Set 10 | kawalu
# Processing Record 37 of Set 10 | le creusot
# Processing Record 38 of Set 10 | sibiti
# Processing Record 39 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | caravelas
# Processing Record 41 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 10 | karonga
# Processing Record 43 of Set 10 | smithers
# Processing Record 44 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 10 | nador
# Processing Record 46 of Set 10 | sheridan
# Processing Record 47 of Set 10 | viedma
# Processing Record 48 of Set 10 | dubti
# Processing Record 49 of Set 10 | lakes entrance
# Processing Record 50 of Set 10 | baghdad
# Processing Record 1 of Set 11 | belaya gora
# Processing Record 2 of Set 11 | tevaitoa
# Processing Record 3 of Set 11 | lebanon
# Processing Record 4 of Set 11 | grande prairie
# Processing Record 5 of Set 11 | isernia
# Processing Record 6 of Set 11 | marau
# Processing Record 7 of Set 11 | rumphi
# Processing Record 8 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 11 | hondo
# Processing Record 10 of Set 11 | bergerac
# Processing Record 11 of Set 11 | znamenskoye
# Processing Record 12 of Set 11 | augustow
# Processing Record 13 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 11 | ciudad bolivar
# Processing Record 15 of Set 11 | le mans
# Processing Record 16 of Set 11 | zajecar
# Processing Record 17 of Set 11 | buritama
# Processing Record 18 of Set 11 | quelimane
# Processing Record 19 of Set 11 | alpena
# Processing Record 20 of Set 11 | baykit
# Processing Record 21 of Set 11 | nuuk
# Processing Record 22 of Set 11 | panjakent
# Processing Record 23 of Set 11 | merrill
# Processing Record 24 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | abalak
# Processing Record 27 of Set 11 | san patricio
# Processing Record 28 of Set 11 | pochutla
# Processing Record 29 of Set 11 | nelson bay
# Processing Record 30 of Set 11 | kununurra
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | edd
# Processing Record 33 of Set 11 | vila franca do campo
# Processing Record 34 of Set 11 | trinidad
# Processing Record 35 of Set 11 | deputatskiy
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | inhambane
# Processing Record 38 of Set 11 | voloshka
# Processing Record 39 of Set 11 | haines junction
# Processing Record 40 of Set 11 | naze
# Processing Record 41 of Set 11 | coruripe
# Processing Record 42 of Set 11 | dukat
# Processing Record 43 of Set 11 | port keats
# Processing Record 44 of Set 11 | kalang
# Processing Record 45 of Set 11 | calarca
# Processing Record 46 of Set 11 | las matas de farfan
# Processing Record 47 of Set 11 | sayyan
# Processing Record 48 of Set 11 | bentiu
# Processing Record 49 of Set 11 | tilichiki
# Processing Record 50 of Set 11 | pervomayskiy
# Processing Record 1 of Set 12 | carutapera
# Processing Record 2 of Set 12 | mogadishu
# Processing Record 3 of Set 12 | urucara
# Processing Record 4 of Set 12 | celendin
# Processing Record 5 of Set 12 | mstera
# Processing Record 6 of Set 12 | tanabe
# Processing Record 7 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 12 | urdoma
# Processing Record 9 of Set 12 | steyr
# Processing Record 10 of Set 12 | puerto baquerizo moreno
# Processing Record 11 of Set 12 | borazjan
# Processing Record 12 of Set 12 | broken hill
# Processing Record 13 of Set 12 | reidsville
# Processing Record 14 of Set 12 | road town
# Processing Record 15 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 16 of Set 12 | belmonte
# Processing Record 17 of Set 12 | aiken
# Processing Record 18 of Set 12 | taybad
# Processing Record 19 of Set 12 | mopipi
# Processing Record 20 of Set 12 | buxton
# Processing Record 21 of Set 12 | ginda
# Processing Record 22 of Set 12 | ryotsu
# Processing Record 23 of Set 12 | batagay-alyta
# Processing Record 24 of Set 12 | portland
# Processing Record 25 of Set 12 | rassvet
# Processing Record 26 of Set 12 | krasnyy kommunar
# Processing Record 27 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 12 | morro bay
# Processing Record 29 of Set 12 | abu dhabi
# Processing Record 30 of Set 12 | kintinku
# Processing Record 31 of Set 12 | varazdin
# Processing Record 32 of Set 12 | pitsunda
# Processing Record 33 of Set 12 | nybro
# Processing Record 34 of Set 12 | south venice
# Processing Record 35 of Set 12 | hvolsvollur
# Processing Record 36 of Set 12 | goure
# Processing Record 37 of Set 12 | vestmannaeyjar
# Processing Record 38 of Set 12 | mossendjo
# Processing Record 39 of Set 12 | zhigalovo
# Processing Record 40 of Set 12 | woodward
# Processing Record 41 of Set 12 | bulgan
# Processing Record 42 of Set 12 | terney
# Processing Record 43 of Set 12 | skjaerhollen
# City not found. Skipping...
# Processing Record 44 of Set 12 | luderitz
# Processing Record 45 of Set 12 | tolyatti
# Processing Record 46 of Set 12 | bud
# Processing Record 47 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 48 of Set 12 | alexandria
# Processing Record 49 of Set 12 | haghartsin
# Processing Record 50 of Set 12 | yulara
# Processing Record 1 of Set 13 | ust-kuyga
# Processing Record 2 of Set 13 | kamaishi
# Processing Record 3 of Set 13 | bilibino
# Processing Record 4 of Set 13 | ilulissat
# Processing Record 5 of Set 13 | diego de almagro
# Processing Record 6 of Set 13 | sibu
# Processing Record 7 of Set 13 | milkovo
# Processing Record 8 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 9 of Set 13 | elizabethtown
# Processing Record 10 of Set 13 | salinopolis
# Processing Record 11 of Set 13 | leningradskiy
# Processing Record 12 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 13 of Set 13 | kungurtug
# Processing Record 14 of Set 13 | shenzhen
# Processing Record 15 of Set 13 | fort nelson
# Processing Record 16 of Set 13 | san rafael
# Processing Record 17 of Set 13 | vitoria do mearim
# Processing Record 18 of Set 13 | belyy yar
# Processing Record 19 of Set 13 | lobva
# Processing Record 20 of Set 13 | avera
# Processing Record 21 of Set 13 | gao
# Processing Record 22 of Set 13 | knokke-heist
# Processing Record 23 of Set 13 | sorland
# Processing Record 24 of Set 13 | san juan
# Processing Record 25 of Set 13 | vaitape
# Processing Record 26 of Set 13 | skjervoy
# Processing Record 27 of Set 13 | nsukka
# Processing Record 28 of Set 13 | phek
# Processing Record 29 of Set 13 | olginskaya
# Processing Record 30 of Set 13 | pangkalanbuun
# Processing Record 31 of Set 13 | benguela
# Processing Record 32 of Set 13 | sur
# Processing Record 33 of Set 13 | luwero
# Processing Record 34 of Set 13 | niederfeulen
# Processing Record 35 of Set 13 | san jose
# Processing Record 36 of Set 13 | yunhe
# Processing Record 37 of Set 13 | san clemente
# Processing Record 38 of Set 13 | birao
# Processing Record 39 of Set 13 | tabuk
# Processing Record 40 of Set 13 | herat
# Processing Record 41 of Set 13 | dudinka
# Processing Record 42 of Set 13 | san luis
# Processing Record 43 of Set 13 | eydhafushi
# Processing Record 44 of Set 13 | andrews
# Processing Record 45 of Set 13 | sloboda
# Processing Record 46 of Set 13 | verkhniye kigi
# Processing Record 47 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 13 | albert
# Processing Record 49 of Set 13 | horki
# Processing Record 50 of Set 13 | aksu
# Processing Record 1 of Set 14 | high level
# Processing Record 2 of Set 14 | sao gabriel da cachoeira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 1. Import the WeatherPy_database.csv file. 

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#city_data_df = pd.read.csv("Weather_Database/WeatherPy_Database.csv")
#city_data_df.head()
#pd.read_csv("Weather_Database/WeatherPy_Database.csv")
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Yellowknife  62.4560 -114.3525    265.44        57          20
# 1           Thio -21.6167  166.2167    301.13        67          98
# 2         Lompoc  34.6391 -120.4579    289.70        77           0
# 3         Castro -24.7911  -50.0119    283.83        98           8
# 4        Mataura -46.1927  168.8643    289.53        46          20
# 5  Mar Del Plata -38.0023  -57.5575    290.42        92           0
# 6   Krasnoselkup  65.7000   82.4667    263.80        92         100
# 7          Kenai  60.5544 -151.2583    280.39        56         100
# 8        Rikitea -23.1203 -134.9692    298.97        63           2
# 9     Walvis Bay -22.9575   14.5053    284.68        93           8
#
#    Wind Speed Country                 Date
# 0        2.57      CA  2022-04-18 02:25:44
# 1        1.12      NC  2022-04-18 02:25:45
# 2        6.69      US  2022-04-18 02:22:22
# 3        2.24      BR  2022-04-18 02:23:01
# 4        1.27      NZ  2022-04-18 02:25:45
# 5        4.92      AR  2022-04-18 02:25:46
# 6        7.00      RU  2022-04-18 02:25:46
# 7        2.06      US  2022-04-18 02:20:58
# 8        4.59      PF  2022-04-18 02:25:46
# 9        2.06      NA  2022-04-18 02:25:47

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
mintemp = float(input("Inform the minimum Temp preferable:"))
maxtemp = float(input("Inform the maximum Temp preferable:"))
# Out:
# Inform the minimum Temp preferable:200
# Inform the maximum Temp preferable:300

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_data_temp_df = city_data_df.loc[(city_data_df["Max Temp"] >= mintemp) & (city_data_df["Max Temp"] <= maxtemp)]
city_data_temp_df
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0                 Yellowknife  62.4560 -114.3525    265.44        57
# 2                      Lompoc  34.6391 -120.4579    289.70        77
# 3                      Castro -24.7911  -50.0119    283.83        98
# 4                     Mataura -46.1927  168.8643    289.53        46
# 5               Mar Del Plata -38.0023  -57.5575    290.42        92
# ..                        ...      ...       ...       ...       ...
# 584                    Albert  50.0009    2.6510    281.92        63
# 585                     Horki  54.2861   30.9842    272.58        95
# 586                      Aksu  41.1231   80.2644    290.55        12
# 587                High Level  58.5169 -117.1360    265.21        67
# 588  Sao Gabriel Da Cachoeira  -0.1303  -67.0892    295.99        98
#
#      Cloudiness  Wind Speed Country                 Date
# 0            20        2.57      CA  2022-04-18 02:25:44
# 2             0        6.69      US  2022-04-18 02:22:22
# 3             8        2.24      BR  2022-04-18 02:23:01
# 4            20        1.27      NZ  2022-04-18 02:25:45
# 5             0        4.92      AR  2022-04-18 02:25:46
# ..          ...         ...     ...                  ...
# 584           0        1.03      FR  2022-04-18 02:42:49
# 585         100        6.36      BY  2022-04-18 02:42:49
# 586           4        3.27      CN  2022-04-18 02:42:50
# 587         100        5.66      CA  2022-04-18 02:43:50
# 588          88        0.86      BR  2022-04-18 02:43:50
#
# [491 rows x 9 columns]

# %%
# 4a. Determine if there are any empty rows.
city_data_temp_df.isnull().sum()
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = city_data_temp_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp      Lat       Lng Hotel Name
# 0     Yellowknife      CA    265.44  62.4560 -114.3525
# 2          Lompoc      US    289.70  34.6391 -120.4579
# 3          Castro      BR    283.83 -24.7911  -50.0119
# 4         Mataura      NZ    289.53 -46.1927  168.8643
# 5   Mar Del Plata      AR    290.42 -38.0023  -57.5575
# 6    Krasnoselkup      RU    263.80  65.7000   82.4667
# 7           Kenai      US    280.39  60.5544 -151.2583
# 8         Rikitea      PF    298.97 -23.1203 -134.9692
# 9      Walvis Bay      NA    284.68 -22.9575   14.5053
# 10    Tuktoyaktuk      CA    264.15  69.4541 -133.0374

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"

    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found - Skip")
# Out:
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip
# Hotel not found - Skip

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df=hotel_df[hotel_df["Hotel Name"].astype(bool)]
clean_hotel_df
# Out:
#                          City Country  Max Temp      Lat       Lng  \
# 0                 Yellowknife      CA    265.44  62.4560 -114.3525
# 2                      Lompoc      US    289.70  34.6391 -120.4579
# 3                      Castro      BR    283.83 -24.7911  -50.0119
# 4                     Mataura      NZ    289.53 -46.1927  168.8643
# 5               Mar Del Plata      AR    290.42 -38.0023  -57.5575
# ..                        ...     ...       ...      ...       ...
# 584                    Albert      FR    281.92  50.0009    2.6510
# 585                     Horki      BY    272.58  54.2861   30.9842
# 586                      Aksu      CN    290.55  41.1231   80.2644
# 587                High Level      CA    265.21  58.5169 -117.1360
# 588  Sao Gabriel Da Cachoeira      BR    295.99  -0.1303  -67.0892
#
#                                    Hotel Name
# 0                          The Explorer Hotel
# 2    Holiday Inn Express Lompoc, an IHG Hotel
# 3                              CHACARA BAILLY
# 4                               Ellie's Villa
# 5                    Gran Hotel Mar del Plata
# ..                                        ...
# 584                     Hotel de la Basilique
# 585                 Sauna V Gorkakh. Zhil'ye.
# 586                      Pudong Holiday Hotel
# 587            Days Inn by Wyndham High Level
# 588  Alarne - Área De Lazer Do Alto Rio Negro
#
# [428 rows x 6 columns]

# %%
# 8a. Create the output File (CSV)

output_data_file = "WeatherPy_vacation.csv" 

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>Temp Max {Max Temp} °C</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations =clean_hotel_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
